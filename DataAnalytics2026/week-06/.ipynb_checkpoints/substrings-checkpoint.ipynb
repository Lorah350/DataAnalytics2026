# %%
# Exercise 2.A Using built-in functions
## Lab 1. Working with names – parsing strings

test_name = 'John Doe'

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]
            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")
            break

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
parse_and_display(test_list[1])
# Out:
# Full name: JB Oinonen
# First name: JB
# Last name: Oinonen

# %%
parse_and_display(test_list[2])
# Out:
# Full name: Ken Penn
# First name: Ken
# Last name: Penn

# %%
parse_and_display('Lorah Mwembe')
# Out:
# Full name: Lorah Mwembe
# First name: Lorah
# Last name: Mwembe

# %%
                   CHALLENGE FUNCTION

# %%
def parse_and_display2(name):
    parts = name.split()

    if len(parts) == 1:
        first = parts[0]
        print(f"Full name: {name}")
        print(f"Single name: {first}")

    elif len(parts) == 2:
        first, last = parts
        print(f"Full name: {name}")
        print(f"First name: {first}")
        print(f"Last name: {last}")

    elif len(parts) == 3:
        first, middle, last = parts
        print(f"Full name: {name}")
        print(f"First name: {first}")
        print(f"Middle name: {middle}")
        print(f"Last name: {last}")

# %%
parse_and_display2('Lorde')
parse_and_display2('Billie Eilish')
parse_and_display2('Megan Thee Stallion')
# Out:
# Full name: Lorde
# Single name: Lorde
# Full name: Billie Eilish
# First name: Billie
# Last name: Eilish
# Full name: Megan Thee Stallion
# First name: Megan
# Middle name: Thee
# Last name: Stallion
