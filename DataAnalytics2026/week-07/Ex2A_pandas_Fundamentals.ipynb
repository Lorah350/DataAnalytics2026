# %% [markdown]
# # Exercise 2.A Fundamentals of pandas
#
# In this exercise, I’m stepping into the world of pandas — the data‑analysis besty that lets me organize, clean, and explore data like a pro. Let’s get into it.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series
#
# Starting simple: turning regular Python objects into pandas Series. Basically giving them a glow‑up.

# %%
aa = [1, 2, 3, 4]
ab = (5, 6, 7, 8)
ac = {9, 10, 11, 12}
ad = {
    'first': 13,
    'second': 14,
    'third': 15,
    'fourth': 16
}

# %%
ser1 = pd.Series(aa)
ser2 = pd.Series(ab)
ser3 = pd.Series(ac)
ser4 = pd.Series(ad)

print(ser1)
print(ser2)
print(ser3)
print(ser4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 ser1 = pd.Series(aa)
#       2 ser2 = pd.Series(ab)
# ----> 3 ser3 = pd.Series(ac)
#       4 ser4 = pd.Series(ad)
#       5
#       6 print(ser1)
#
# File c:\Users\lorah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:514, in Series.__init__(self, data, index, dtype, name, copy)
#     512         data = data.copy(deep=True)
#     513 else:
# --> 514     data = sanitize_array(data, index, dtype, copy)
#     515     data = SingleBlockManager.from_array(data, index, refs=refs)
#     517 NDFrame.__init__(self, data)
#
# File c:\Users\lorah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\construction.py:656, in sanitize_array(data, index, dtype, copy, allow_2d)
#     647     return sanitize_array(
#     648         data,
#     649         index=index,
# ...

# %%
ser5 = pd.Series(17, 18, 19, 20)

# Comment:
# TypeError: Series() takes 1 positional argument but 4 were given.
# pandas said “bestyyy… I need these values inside a list or array, not thrown at me raw.”

# %% [markdown]
# ## DataFrames from Series
#
# Now I’m leveling up: turning Series into DataFrames and watching how pandas behaves when things line up… and when they don’t.

# %%
df1 = pd.DataFrame(ser1)
df1

# %%
df1.insert(1, 'col2', ser2)
df1.insert(2, 'col3', ser3)
df1

# %%
df1.insert(3, 'col4', ser4)
df1

# Comment:
# ser4 came from a dictionary, so pandas used the dictionary KEYS as the index.
# Since those keys don’t match df1’s existing index (0–3), pandas filled the column with NaN.
# Basically: “indexes don’t match, so I’m doing my best.”

# %%
df1.loc[4] = [5, 9, 12, 0]
df1

# %%
## Reading Data into a DataFrame

Time to bring in real CSV files and let pandas show off.

# %%
df2 = pd.read_csv("sakila_example.csv")
df2

# %%
df2.head(5)

# %%
df2.tail(10)

# %%
df2.info()

# %% [markdown]
# From the info results, I can see:
# - How many rows and columns the dataset has.
# - Which columns have missing values (pandas loves to snitch on NaNs).
# - The data types for each column, which tells me how pandas plans to treat them.

# %%
df2.describe()

# %% [markdown]
# Useful insights:
# - I can quickly see averages, mins, maxes, and standard deviations.
# - Great for spotting outliers or weird values.
#
# Less useful:
# - describe() ignores non‑numeric columns, so anything text‑based gets left out.

# %%
df3 = pd.read_csv("northwind_example.csv")
df3

# %%
df3.describe()

# %% [markdown]
# The insights here depend on the dataset:
# - Numeric columns get summarized just like before.
# - If df3 has different types of data than df2, the summary will look different.
# - The differences happen because describe() only summarizes numeric columns by default.

# %% [markdown]
# ## Coding a DataFrame
#
# Now I’m building a DataFrame from scratch — my own little dataset.

# %%
test_data = {
    'ID': [1, 2, 3, 4, 5, 6, 7, 8],
    'Name': ['Alicia', 'Bob', 'Charlie', 'Dominic', 'Eve', 'Frank', 'Grace', 'Heidi'],
    'Age': [25, np.nan, 22, 19, 31, 35, np.nan, 18],
    'City': ['NY', 'LA', 'Chicago', 'Houston', 'Phoenix', 'Boston', 'Austin', 'San Diego'],
    'Score': [85, 92, -1, 65, 78, np.nan, 55, 90]
}

# %%
df4 = pd.DataFrame(test_data)
df4

# %%
df4.to_csv("test_data.csv", index=False)
